# %% [markdown]
# # Examples

# %%
import numpy as np

from pypolycontain.objects import zonotope,unitbox
from pypolycontain.visualize import visualize
    
G=np.random.random((2,11))-0.8
x=np.random.random((2,1))
Z=zonotope(x,G)

B=unitbox(2)
HB=B.H_polytope

# %%
visualize([Z,HB],alpha=0.7)
